# %%
# Install required packages
# %pip install pytest

# Skip writing pyc files on readonly filesystem
import sys
sys.dont_write_bytecode = True

print("✅ Setup complete!")

# %%
import os
import sys

# Add project directories to Python path
repo_root = "/Workspace/Users/sahil.borhade@nonstopio.com/DataBricks-Unit-Testing>"  # Replace with your actual path
src_path = os.path.join(repo_root, "src")
tests_path = os.path.join(repo_root, "tests")

sys.path.append(src_path)
sys.path.append(tests_path)

print(f"Added paths:")
print(f"  Source: {src_path}")
print(f"  Tests: {tests_path}")

# %%
# Import and run tests
from test_myfunctions import run_all_tests

# Run all tests
success = run_all_tests()

if success:
    print("\n✅ All unit tests completed successfully!")
else:
    print("\n❌ Some tests failed. Check output above.")
    raise Exception("Unit tests failed")
